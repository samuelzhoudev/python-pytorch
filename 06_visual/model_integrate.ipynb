# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from collections import Counter

#定义一些超参数 
BATCHSIZE=100
DOWNLOAD_MNIST=False
EPOCHES=20
LR=0.001

# %%
class CNNNet(nn.Module):
    def __init__(self):
        super(CNNNet,self).__init__()
        self.conv1 = nn.Conv2d(in_channels=3,out_channels=16,kernel_size=5,stride=1)
        self.pool1 = nn.MaxPool2d(kernel_size=2,stride=2)
        self.conv2 = nn.Conv2d(in_channels=16,out_channels=36,kernel_size=3,stride=1)
        self.pool2 = nn.MaxPool2d(kernel_size=2,stride=2)
        self.fc1 = nn.Linear(1296,128)
        self.fc2 = nn.Linear(128,10)
        
    def forward(self,x):
        x=self.pool1(F.relu(self.conv1(x)))
        x=self.pool2(F.relu(self.conv2(x)))
        #print(x.shape)
        x=x.view(-1,36*6*6)
        x=F.relu(self.fc2(F.relu(self.fc1(x))))
        return x

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net,self).__init__()
        self.conv1 = nn.Conv2d(3,16,5)
        self.pool1 = nn.MaxPool2d(2,2)
        self.conv2 = nn.Conv2d(16,36,5)
        self.pool2 = nn.MaxPool2d(2,2)
        self.aap = nn.AdaptiveAvgPool2d(1)
        self.fc3 = nn.Linear(36,10)

    def forward(self, x):
        x = self.pool1(F.relu(self.conv1(x)))
        x = self.pool2(F.relu(self.conv2(x)))
        x = self.aap(x)
        x = x.view(x.shape[0],-1)
        x = self.fc3(x)
        return x

# %%
class LeNet(nn.Module):
    def __init__(self):
        super(LeNet,self).__init__()
        self.conv1 = nn.Conv2d(3,6,5)
        self.conv2 = nn.Conv2d(6,16,5)
        self.fc1 = nn.Linear(16*5*5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84,10)
        
    def forward(self, x):
        out = F.relu(self.conv1(x))
        out = F.max_pool2d(out, 2)
        out = F.relu(self.conv2(out))
        out = F.max_pool2d(out, 2)
        out = out.view(out.size(0),-1)
        out = F.relu(self.fc1(out))
        out = F.relu(self.fc2(out))
        out = self.fc3(out)
        return out

# %%
cfg = {
    'VGG16': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512, 'M', 512, 512, 512, 'M'],
    'VGG19': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 256, 'M', 512, 512, 512, 512, 'M', 512, 512, 512, 512, 'M'],
}
class VGG(nn.Module):
    def __init__(self, vgg_name):
        super(VGG, self).__init__()
        self.features = self._make_layers(cfg[vgg_name])
        self.classifier = nn.Linear(512, 10)

    def forward(self, x):
        out = self.features(x)
        out = out.view(out.size(0), -1)
        out = self.classifier(out)
        return out
    
    def _make_layers(self, cfg):
        layers = []
        in_channels = 3
        for x in cfg:
            if x == 'M':
                layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
            else:
                layers += [nn.Conv2d(in_channels, x, kernel_size=3, padding = 1),
                           nn.BatchNorm2d(x),
                           nn.ReLU(inplace=True)                          
                          ]
                in_channels = x
        layers += [nn.AvgPool2d(kernel_size=1, stride=1)]
        return nn.Sequential(*layers)

# %%
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('==>Preparing data..')
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465),(0.2023, 0.1994, 0.2010))
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=False, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=128, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=False, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse','ship', 'truck')

print('==> Building model..')
net1 = CNNNet()
net2 = Net()
net3 = LeNet()
net4 = VGG('VGG16')
# Out:
# ==>Preparing data..
# ==> Building model..

# %%
#把3个网络模型放在一个列表里
mlps=[net1.to(device),net2.to(device),net3.to(device)]
optimizer = torch.optim.Adam([{"params":mlp.parameters()} for mlp in mlps], lr=LR)

loss_function = nn.CrossEntropyLoss()

for ep in range(EPOCHES):
    for img,label in trainloader:
        img,label = img.to(device), label.to(device)
        optimizer.zero_grad()
        for mlp in mlps:
            mlp.train()
            out = mlp(img)
            loss=loss_function(out,label)
            loss.backward()
        optimizer.step()
    
    pre=[]
    vote_correct=0
    mlps_correct=[0 for i in range(len(mlps))]
    
    for img,label in testloader:
        img,label = img.to(device),label.to(device)
        for i, mlp in enumerate(mlps):
            mlp.eval()
            out=mlp(img)
            
            _,prediction = torch.max(out,1)
            pre_num = prediction.cpu().numpy()
            mlps_correct[i]+=(pre_num==label.cpu().numpy()).sum()
            
            pre.append(pre_num)
        arr = np.array(pre)
        pre.clear()
        result=[Counter(arr[:,i]).most_common(1)[0][0] for i in range(BATCHSIZE)]
        vote_correct += (result == label.cpu().numpy()).sum()
    print('epoch:' + str(ep) + "集成模型的正确率" + str(vote_correct/len(testloader)))
    
    for idx, correct in enumerate(mlps_correct):
        print("模型"+str(idx)+"正确率为："+str(correct/len(testloader)))
# Out:
# epoch:0集成模型的正确率47.37
# 模型0正确率为：42.58
# 模型1正确率为：39.21
# 模型2正确率为：44.67
# epoch:1集成模型的正确率53.15
# 模型0正确率为：52.22
# 模型1正确率为：44.78
# 模型2正确率为：47.88
# epoch:2集成模型的正确率55.85
# 模型0正确率为：53.61
# 模型1正确率为：46.58
# 模型2正确率为：51.34
# epoch:3集成模型的正确率59.56
# 模型0正确率为：57.19
# 模型1正确率为：50.63
# 模型2正确率为：53.89
# epoch:4集成模型的正确率60.63
# 模型0正确率为：57.67
# 模型1正确率为：51.42
# 模型2正确率为：54.72
# epoch:5集成模型的正确率61.87
# 模型0正确率为：59.18
# 模型1正确率为：54.09
# 模型2正确率为：57.0
# epoch:6集成模型的正确率63.66
# 模型0正确率为：59.19
# 模型1正确率为：54.87
# 模型2正确率为：58.66
# epoch:7集成模型的正确率64.25
# 模型0正确率为：61.14
# 模型1正确率为：55.22
# 模型2正确率为：59.29
# epoch:8集成模型的正确率65.68
# 模型0正确率为：61.06
# 模型1正确率为：57.14
# 模型2正确率为：60.19
# epoch:9集成模型的正确率66.56
# 模型0正确率为：62.24
# 模型1正确率为：56.89
# 模型2正确率为：61.11
# epoch:10集成模型的正确率67.7
# 模型0正确率为：64.75
# 模型1正确率为：57.78
# 模型2正确率为：60.88
# epoch:11集成模型的正确率66.2
# 模型0正确率为：64.2
# 模型1正确率为：56.88
# 模型2正确率为：60.7
# epoch:12集成模型的正确率68.99
# 模型0正确率为：65.78
# 模型1正确率为：58.52
# 模型2正确率为：62.72
# epoch:13集成模型的正确率69.13
# 模型0正确率为：66.39
# 模型1正确率为：59.72
# 模型2正确率为：61.46
# epoch:14集成模型的正确率69.81
# 模型0正确率为：66.71
# 模型1正确率为：58.8
# 模型2正确率为：62.65
# epoch:15集成模型的正确率69.77
# 模型0正确率为：65.68
# 模型1正确率为：58.75
# 模型2正确率为：62.98
# epoch:16集成模型的正确率70.32
# 模型0正确率为：66.82
# 模型1正确率为：59.9
# 模型2正确率为：63.68
# epoch:17集成模型的正确率71.14
# 模型0正确率为：67.24
# 模型1正确率为：61.71
# 模型2正确率为：63.55
# epoch:18集成模型的正确率71.46
# 模型0正确率为：68.11
# 模型1正确率为：61.43
# 模型2正确率为：65.21
# epoch:19集成模型的正确率70.55
# 模型0正确率为：66.56
# 模型1正确率为：60.17
# 模型2正确率为：64.11

# %%
mlps = [net4.to(device)]
optimizer = torch.optim.Adam([{"params":mlp.parameters()} for mlp in mlps], lr=LR) 

loss_function = nn.CrossEntropyLoss() 

for ep in range(EPOCHES):
    for img,label in trainloader:
        img,label = img.to(device),label.to(device)
        optimizer.zero_grad()
        for mlp in mlps:
            mlp.train()
            out=mlp(img)
            loss=loss_function(out,label)
            loss.backward()
        optimizer.step()
    
    pre=[]
    vote_correct=0
    mlps_correct=[0 for i in range(len(mlps))]
    for img,label in testloader:
        img,label = img.to(device), label.to(device)
        for i, mlp in enumerate(mlps):
            mlp.eval()
            out=mlp(img)
            
            _,prediction = torch.max(out,1)
            pre_num=prediction.cpu().numpy()
            mlps_correct[i]+=(pre_num==label.cpu().numpy()).sum()
            
            pre.append(pre_num)
        arr = np.array(pre)
        pre.clear()
        result=[Counter(arr[:, i]).most_common(1)[0][0] for i in range(BATCHSIZE)]
        vote_correct += (result == label.cpu().numpy()).sum()
    #print("epoch:" + str(ep) + "集成模型的正确率" + str(vote_correct/len(testloader)))
    
    for idx, correct in enumerate(mlps_correct):
        print("VGG16模型迭代" + str(ep) + "次的正确率为："+str(correct/len(testloader)))
# Out:
# VGG16模型迭代0次的正确率为：46.5
# VGG16模型迭代1次的正确率为：62.51
# VGG16模型迭代2次的正确率为：72.6
# VGG16模型迭代3次的正确率为：76.55
# VGG16模型迭代4次的正确率为：79.2
# VGG16模型迭代5次的正确率为：80.28
# VGG16模型迭代6次的正确率为：82.18
# VGG16模型迭代7次的正确率为：82.67
# VGG16模型迭代8次的正确率为：82.63
# VGG16模型迭代9次的正确率为：83.52
# VGG16模型迭代10次的正确率为：85.27
# VGG16模型迭代11次的正确率为：86.64
# VGG16模型迭代12次的正确率为：86.04
# VGG16模型迭代13次的正确率为：87.69
# VGG16模型迭代14次的正确率为：86.42
# VGG16模型迭代15次的正确率为：87.35
# VGG16模型迭代16次的正确率为：87.75
# VGG16模型迭代17次的正确率为：88.43
# VGG16模型迭代18次的正确率为：87.87
# VGG16模型迭代19次的正确率为：88.91
